# %%
import pandas as pd

# %%
game_ranking=pd.read_csv('game_ranking.csv')
game_ranking.head()
# Out:
#    rank      id                          name  \
# 0     1  174430                    Gloomhaven
# 1     2  161936     Pandemic Legacy: Season 1
# 2     3  224517             Brass: Birmingham
# 3     4  167791             Terraforming Mars
# 4     5  291457  Gloomhaven: Jaws of the Lion
#
#                                          description  bggrating  avgrating  \
# 0  Vanquish monsters with strategic cardplay. Ful...      8.534       8.77
# 1  Mutating diseases are spreading around the wor...      8.453       8.61
# 2  Build networks, grow industries, and navigate ...      8.403       8.67
# 3  Compete with rival CEOs to make Mars habitable...      8.279       8.43
# 4  Vanquish monsters with strategic cardplay in a...      8.256       8.77
#
#    numvoter        date
# 0     44979  2021-08-10
# 1     43369  2021-08-10
# 2     22391  2021-08-10
# 3     69407  2021-08-10
# 4     12192  2021-08-10

# %%
bgg_df=pd.read_csv('bgg_df_rank.csv')
bgg_df.head()
# Out:
#    Index  rank                               name  year_published  \
# 0      0     1                         Gloomhaven            2017
# 1      1     2         Pandemic Legacy:  Saison 1            2015
# 2      2     3                   Brass. Бірмінгем            2018
# 3      3     4              A Mars terraformálása            2016
# 4      4     5  Gloomhaven: Die Pranken des Löwen            2020
#
#    min_players  max_players  playing_time  age  boardgamecategory  \
# 0            1            4           120   14                NaN
# 1            2            4            60   13                NaN
# 2            2            4           120   14                NaN
# 3            1            5           120   12                NaN
# 4            1            4           120   14                NaN
#
#                                            thumbnail
# 0  https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZ...
# 1  https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6K...
# 2  https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg...
# 3  https://cf.geekdo-images.com/wg9oOLcsKvDesSUdZ...
# 4  https://cf.geekdo-images.com/_HhIdavYW-hid20Iq...

# %%
join_df=pd.merge(game_ranking,bgg_df, on=['rank','name'], how='outer')
join_df
# Out:
#       rank        id                             name  \
# 0        1  174430.0                       Gloomhaven
# 1        2  161936.0        Pandemic Legacy: Season 1
# 2        3  224517.0                Brass: Birmingham
# 3        4  167791.0                Terraforming Mars
# 4        5  291457.0     Gloomhaven: Jaws of the Lion
# ...    ...       ...                              ...
# 2870  2436       NaN  1 Nacht Weerwolven & Waaghalzen
# 2871  2437       NaN                    Dolina Królów
# 2872  2438       NaN                          Bonfire
# 2873  2439       NaN                    Ajax Chessmen
# 2874  2440       NaN         Time's Up! Title Recall!
#
#                                             description  bggrating  avgrating  \
# 0     Vanquish monsters with strategic cardplay. Ful...      8.534       8.77
# 1     Mutating diseases are spreading around the wor...      8.453       8.61
# 2     Build networks, grow industries, and navigate ...      8.403       8.67
# 3     Compete with rival CEOs to make Mars habitable...      8.279       8.43
# 4     Vanquish monsters with strategic cardplay in a...      8.256       8.77
# ...                                                 ...        ...        ...
# 2870                                                NaN        NaN        NaN
# 2871                                                NaN        NaN        NaN
# 2872                                                NaN        NaN        NaN
# 2873                                                NaN        NaN        NaN
# 2874                                                NaN        NaN        NaN
#
#       numvoter        date   Index  year_published  min_players  max_players  \
# 0      44979.0  2021-08-10     0.0          2017.0          1.0          4.0
# 1      43369.0  2021-08-10     NaN             NaN          NaN          NaN
# 2      22391.0  2021-08-10     NaN             NaN          NaN          NaN
# 3      69407.0  2021-08-10     NaN             NaN          NaN          NaN
# 4      12192.0  2021-08-10     NaN             NaN          NaN          NaN
# ...        ...         ...     ...             ...          ...          ...
# 2870       NaN         NaN  2435.0          2014.0          3.0         10.0
# 2871       NaN         NaN  2436.0          2009.0          2.0          4.0
# 2872       NaN         NaN  2437.0          2020.0          1.0          4.0
# 2873       NaN         NaN  2438.0          1475.0          2.0          2.0
# 2874       NaN         NaN  2439.0          2008.0          4.0         18.0
#
#       playing_time   age  boardgamecategory  \
# 0            120.0  14.0                NaN
# 1              NaN   NaN                NaN
# 2              NaN   NaN                NaN
# 3              NaN   NaN                NaN
# 4              NaN   NaN                NaN
# ...            ...   ...                ...
# 2870          10.0   8.0                NaN
# 2871          90.0  12.0                NaN
# 2872         100.0  12.0                NaN
# 2873          60.0   6.0                NaN
# 2874          60.0  12.0                NaN
#
#                                               thumbnail
# 0     https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2870  https://cf.geekdo-images.com/KLDb0vR3w8mfaHgIG...
# 2871  https://cf.geekdo-images.com/lt07T2HIr_r7JerYd...
# 2872  https://cf.geekdo-images.com/q9sYvC0Tt-1mEiuKn...
# 2873  https://cf.geekdo-images.com/0-DjGBOko6RV8zg5e...
# 2874  https://cf.geekdo-images.com/XVqx-bp37COAHcyYU...
#
# [2875 rows x 16 columns]

# %%
join_df.dtypes
# Out:
# rank                   int64
# id                   float64
# name                  object
# description           object
# bggrating            float64
# avgrating            float64
# numvoter             float64
# date                  object
# Index                float64
# year_published       float64
# min_players          float64
# max_players          float64
# playing_time         float64
# age                  float64
# boardgamecategory    float64
# thumbnail             object
# dtype: object

# %%
import datetime, requests, time
import xml.etree.ElementTree as ET
import pandas as pd

# %%
# api calls
apiBase = 'https://www.boardgamegeek.com/xmlapi2/'
gameInfo = 'thing?id='
userInfo = 'user?name='
playsInfoByUser = 'plays?username='
playsInfoByGame = 'plays?id='

# %%
# retrieve API call
def get_game_metadata(gameIdList):
    """supply a list of game id's you want to retrive game metadata on.  Output is XML."""
    stringify = ','.join(gameIdList)
    response = requests.get(f'{apiBase}{gameInfo}{stringify}').content
    # add a short sleep so API doesn't throttle - we aren't making that makny calls
    time.sleep(5)
    return response

# %%
def listify_game_metadata(apiResponse):
    """The parses the game metadata XML into a list of lists for import"""
    gameMetadata = []
    gameCategories = []
    gameMechanisms = []
    importDate = datetime.datetime.strftime(datetime.datetime.now().date(), '%Y-%m-%d')

    # game info
    tree = ET.fromstring(apiResponse)

    # iterate through response top level 'item'
    for item in tree.findall('item'):

        # define metadata we want to collect since Type & Id are attributes at the top level we will set them here
        itemType = item.attrib['type']
        itemId = item.attrib['id']      
        itemName = None                 
        itemYearPublished = None                
        itemMinPlayers = None           
        itemMaxPlayers = None           
        itemPlayTime = None             
        itemCategories = []
        itemMechanisms = []
        itemThumbnail = None
        
        # get itemName
        names = item.findall('name')
        for name in names:
            if name.attrib['type'].lower() == 'primary':
                name = name.attrib['value']
                itemName = name
        
        # get itemYearPublished
        publishedYear = item.find('yearpublished')
        itemYearPublished = publishedYear.attrib['value']

        # get itemMinPlayers
        minPlayers = item.find('minplayers')
        itemMinPlayers = minPlayers.attrib['value']

        # get itemMaxPlayers
        maxPlayers = item.find('maxplayers')
        itemMaxPlayers = maxPlayers.attrib['value']

        # get itemPlayingTime
        playingTime = item.find('playingtime')
        itemPlayTime = playingTime.attrib['value']

        # get itemCategories
        categories = item.findall('link')
        for category in categories:
            if 'categor' in category.attrib['type'].lower():
                itemCategories.append(category.attrib['value'])

        # get itemCategories
        mechanisms = item.findall('link')
        for mechanism in mechanisms:
            if 'mechanic' in mechanism.attrib['type'].lower():
                itemMechanisms.append(mechanism.attrib['value'])

        # get itemThumbnail
        thumbnail = item.find('thumbnail')
        itemThumbnail = thumbnail.text

        gameMetadata += tuple([(itemId, itemType, itemName, itemYearPublished, None, itemMinPlayers, itemMaxPlayers,
                         itemPlayTime, itemThumbnail, importDate)])
        
        gameCategories += tuple([(itemId, x) for x in itemCategories])

        gameMechanisms += tuple([(itemId, x) for x in itemMechanisms])
        
    #return [gameMetadata]
    return [gameCategories]
    #return [gameMechanisms]

# %%
idList= ['174430', '161936'] #'224517']
categorylist=[]

for a in idList:
    response = get_game_metadata(str(a))
    res=listify_game_metadata(response)
    count=0
    for i in res:
        categorylist.append([a,res[count][1]])
        count+=1
        
    

    
categorylist
# Out:
# [['174430', ('1', 'Negotiation')], ['161936', ('1', 'Negotiation')]]

# %%
id_df=pd.read_csv('game_ranking.csv')
id_df.head()
# Out:
#    rank      id                          name  \
# 0     1  174430                    Gloomhaven
# 1     2  161936     Pandemic Legacy: Season 1
# 2     3  224517             Brass: Birmingham
# 3     4  167791             Terraforming Mars
# 4     5  291457  Gloomhaven: Jaws of the Lion
#
#                                          description  bggrating  avgrating  \
# 0  Vanquish monsters with strategic cardplay. Ful...      8.534       8.77
# 1  Mutating diseases are spreading around the wor...      8.453       8.61
# 2  Build networks, grow industries, and navigate ...      8.403       8.67
# 3  Compete with rival CEOs to make Mars habitable...      8.279       8.43
# 4  Vanquish monsters with strategic cardplay in a...      8.256       8.77
#
#    numvoter        date
# 0     44979  2021-08-10
# 1     43369  2021-08-10
# 2     22391  2021-08-10
# 3     69407  2021-08-10
# 4     12192  2021-08-10

# %%
idlist=id_df['id'].tolist()
idlist
# Out:
# [174430,
#  161936,
#  224517,
#  167791,
#  291457,
#  233078,
#  220308,
#  187645,
#  182028,
#  193738,
#  162886,
#  12333,
#  115746,
#  169786,
#  84876,
#  173346,
#  120677,
#  124361,
#  28720,
#  266192,
#  167355,
#  177736,
#  205637,
#  183394,
#  164928,
#  96848,
#  237182,
#  199792,
#  3076,
#  102794,
#  175914,
#  31260,
#  170216,
#  205059,
#  221107,
#  276025,
#  316554,
#  285774,
#  180263,
#  284083,
#  192135,
#  266507,
#  247763,
#  55690,
#  126163,
#  2651,
#  185343,
#  209010,
#  164153,
#  216132,
#  251247,
#  35677,
#  230802,
#  184267,
#  72125,
#  312484,
#  25613,
#  125153,
#  256960,
#  124742,
#  191189,
#  161533,
#  121921,
#  159675,
#  521,
#  244521,
#  171623,
#  28143,
#  266810,
#  229853,
#  246900,
#  201808,
#  68448,
#  157354,
#  62219,
#  110327,
#  200680,
#  122515,
#  264220,
#  236457,
#  18602,
#  93,
#  182874,
#  12493,
#  37111,
#  146021,
#  73439,
#  172386,
#  40834,
#  205896,
#  269385,
#  163412,
#  170042,
#  144733,
#  42,
#  203993,
#  281259,
#  178900,
#  102680,
#  132531,
#  225694,
#  36218,
#  2511,
#  30549,
#  155821,
#  198928,
#  172287,
#  233371,
#  196340,
#  127023,
#  175155,
#  266524,
#  175640,
#  263918,
#  161970,
#  103885,
#  146652,
#  34635,
#  218417,
#  262712,
#  233398,
#  147020,
#  4098,
#  163068,
#  104162,
#  118048,
#  14996,
#  148949,
#  233867,
#  150376,
#  43111,
#  244522,
#  9609,
#  43015,
#  271324,
#  77423,
#  274364,
#  314040,
#  54043,
#  287954,
#  17133,
#  221194,
#  128882,
#  253344,
#  155426,
#  103343,
#  82222,
#  10630,
#  70149,
#  220877,
#  188920,
#  217372,
#  39463,
#  14105,
#  199561,
#  239188,
#  463,
#  223321,
#  254640,
#  123260,
#  195421,
#  31627,
#  126042,
#  25021,
#  21050,
#  104006,
#  146508,
#  171131,
#  91,
#  224037,
#  282524,
#  283948,
#  182631,
#  245638,
#  148228,
#  188,
#  146886,
#  215,
#  194655,
#  9209,
#  12,
#  822,
#  109276,
#  176189,
#  129437,
#  54998,
#  296151,
#  9216,
#  188834,
#  555,
#  189932,
#  155068,
#  7854,
#  256916,
#  192291,
#  169426,
#  156129,
#  128621,
#  283155,
#  232832,
#  31481,
#  27833,
#  242302,
#  421,
#  20551,
#  176494,
#  199478,
#  265188,
#  198994,
#  140620,
#  19857,
#  158600,
#  268864,
#  27708,
#  249259,
#  127060,
#  228341,
#  155873,
#  3,
#  209418,
#  118,
#  108745,
#  24181,
#  92828,
#  97207,
#  204583,
#  284378,
#  154203,
#  22545,
#  241451,
#  144344,
#  181279,
#  38453,
#  760,
#  222509,
#  286096,
#  269207,
#  193037,
#  176734,
#  93260,
#  66589,
#  203420,
#  59294,
#  19777,
#  48726,
#  283355,
#  308765,
#  232405,
#  224783,
#  54138,
#  206718,
#  2655,
#  146439,
#  172081,
#  13122,
#  160477,
#  271896,
#  234,
#  139976,
#  165722,
#  209685,
#  187617,
#  101721,
#  172818,
#  40692,
#  45315,
#  46213,
#  140934,
#  136888,
#  181304,
#  246784,
#  77130,
#  54,
#  163967,
#  227789,
#  59959,
#  271055,
#  25292,
#  41114,
#  5,
#  143693,
#  176920,
#  37046,
#  163745,
#  39856,
#  129622,
#  21241,
#  70919,
#  235802,
#  2653,
#  119890,
#  317985,
#  17392,
#  182134,
#  234487,
#  199042,
#  219513,
#  192458,
#  8217,
#  1,
#  25554,
#  257499,
#  172,
#  184921,
#  39683,
#  306735,
#  24480,
#  33160,
#  90137,
#  186751,
#  31594,
#  144592,
#  9217,
#  250458,
#  204305,
#  36932,
#  246192,
#  21348,
#  265736,
#  40765,
#  50,
#  70323,
#  256226,
#  154809,
#  170771,
#  71,
#  121,
#  274637,
#  54625,
#  166669,
#  243,
#  198773,
#  293014,
#  63888,
#  255984,
#  124708,
#  156546,
#  197376,
#  234277,
#  195539,
#  318977,
#  231733,
#  223040,
#  15987,
#  236191,
#  194594,
#  63628,
#  55670,
#  260605,
#  245934,
#  230253,
#  155987,
#  66188,
#  40354,
#  161614,
#  260428,
#  15985,
#  244711,
#  229220,
#  302723,
#  138161,
#  188866,
#  100901,
#  151347,
#  128271,
#  215341,
#  79828,
#  297030,
#  269210,
#  96913,
#  244271,
#  215311,
#  47,
#  66362,
#  295486,
#  176396,
#  128671,
#  27162,
#  11170,
#  111341,
#  274960,
#  105134,
#  137408,
#  25417,
#  150658,
#  34219,
#  18833,
#  192153,
#  270633,
#  92415,
#  5404,
#  62222,
#  157969,
#  128996,
#  270844,
#  712,
#  17226,
#  83330,
#  146791,
#  136063,
#  123123,
#  150,
#  177639,
#  372,
#  194607,
#  62227,
#  95527,
#  162082,
#  158899,
#  98778,
#  13,
#  65781,
#  251658,
#  105551,
#  233312,
#  127398,
#  119506,
#  478,
#  15062,
#  256730,
#  206941,
#  97786,
#  20437,
#  144189,
#  43570,
#  133848,
#  171668,
#  221965,
#  191862,
#  102652,
#  875,
#  193042,
#  300322,
#  240196,
#  262543,
#  147949,
#  58421,
#  304420,
#  171,
#  36553,
#  226522,
#  125618,
#  21790,
#  90419,
#  142379,
#  205398,
#  9674,
#  144797,
#  232043,
#  31999,
#  163968,
#  180974,
#  192836,
#  156858,
#  42052,
#  27173,
#  34119,
#  18,
#  218603,
#  279537,
#  133473,
#  11,
#  133038,
#  12942,
#  156009,
#  97842,
#  245654,
#  475,
#  181530,
#  17405,
#  183562,
#  22827,
#  183251,
#  31730,
#  27746,
#  262215,
#  3685,
#  257501,
#  128780,
#  141572,
#  15363,
#  6249,
#  91312,
#  151022,
#  269144,
#  159508,
#  155703,
#  39351,
#  160010,
#  2346,
#  212445,
#  202426,
#  6472,
#  232414,
#  153938,
#  245655,
#  140603,
#  205359,
#  196326,
#  39938,
#  169255,
#  84419,
#  246684,
#  113924,
#  172308,
#  42776,
#  42215,
#  9625,
#  4390,
#  28023,
#  73171,
#  143519,
#  503,
#  119432,
#  264241,
#  174785,
#  117959,
#  131357,
#  1513,
#  294484,
#  298047,
#  30869,
#  150145,
#  209778,
#  170561,
#  300531,
#  163166,
#  121408,
#  252328,
#  24508,
#  150997,
#  216734,
#  58281,
#  130960,
#  293141,
#  10547,
#  180511,
#  224710,
#  37904,
#  135219,
#  175095,
#  50750,
#  1353,
#  111799,
#  121288,
#  198953,
#  270673,
#  116998,
#  262211,
#  70512,
#  193949,
#  134726,
#  3201,
#  21763,
#  126792,
#  65532,
#  46,
#  30380,
#  173064,
#  256952,
#  220,
#  5782,
#  88,
#  107529,
#  160495,
#  181521,
#  155624,
#  13004,
#  113294,
#  203416,
#  20963,
#  100423,
#  123540,
#  3307,
#  171499,
#  265402,
#  162007,
#  258036,
#  15364,
#  213893,
#  146278,
#  9823,
#  154825,
#  264055,
#  72321,
#  699,
#  193558,
#  269511,
#  143741,
#  242574,
#  68425,
#  168584,
#  284435,
#  586,
#  73761,
#  170624,
#  232219,
#  36235,
#  156336,
#  432,
#  163839,
#  173442,
#  2163,
#  29603,
#  2955,
#  22345,
#  55600,
#  153016,
#  179803,
#  31563,
#  192457,
#  167400,
#  226320,
#  165401,
#  168435,
#  137988,
#  7717,
#  87890,
#  69789,
#  143515,
#  132018,
#  266121,
#  244228,
#  241724,
#  79127,
#  43528,
#  71721,
#  201825,
#  483,
#  214880,
#  26997,
#  227224,
#  156943,
#  2398,
#  158889,
#  220520,
#  285192,
#  247367,
#  256382,
#  47185,
#  200147,
#  242639,
#  183840,
#  110277,
#  233247,
#  20100,
#  270970,
#  231581,
#  160499,
#  169654,
#  162286,
#  38996,
#  170416,
#  203417,
#  21882,
#  131287,
#  249381,
#  91872,
#  190082,
#  24800,
#  135779,
#  41002,
#  244992,
#  1035,
#  2453,
#  30957,
#  18098,
#  40628,
#  148575,
#  177590,
#  117915,
#  171273,
#  163602,
#  296912,
#  156566,
#  179275,
#  12002,
#  169427,
#  181687,
#  230244,
#  224597,
#  28181,
#  166384,
#  113997,
#  244115,
#  12962,
#  528,
#  255692,
#  191051,
#  277085,
#  145659,
#  103886,
#  137269,
#  35570,
#  161417,
#  214887,
#  204516,
#  158435,
#  12891,
#  194879,
#  197443,
#  45,
#  94,
#  139898,
#  51,
#  12902,
#  119788,
#  41066,
#  82421,
#  132028,
#  251678,
#  198830,
#  155362,
#  245961,
#  218333,
#  156689,
#  53953,
#  290236,
#  271518,
#  175117,
#  26566,
#  82420,
#  1041,
#  154458,
#  29368,
#  217780,
#  8125,
#  252153,
#  234671,
#  122298,
#  280480,
#  1345,
#  15512,
#  2181,
#  129948,
#  26990,
#  11825,
#  179172,
#  256570,
#  177678,
#  281442,
#  151004,
#  91514,
#  9440,
#  223953,
#  65244,
#  239942,
#  202670,
#  16747,
#  37380,
#  148319,
#  41,
#  65901,
#  248490,
#  176165,
#  98229,
#  195137,
#  303057,
#  13642,
#  98351,
#  30645,
#  27976,
#  195560,
#  66356,
#  108784,
#  319966,
#  191977,
#  108906,
#  491,
#  106217,
#  172047,
#  207243,
#  240,
#  160851,
#  239464,
#  1465,
#  291572,
#  202408,
#  301880,
#  201921,
#  52461,
#  180593,
#  904,
#  552,
#  8051,
#  258210,
#  206480,
#  234477,
#  227460,
#  131260,
#  169124,
#  207830,
#  216459,
#  2093,
#  27588,
#  147151,
#  274638,
#  59946,
#  284760,
#  266830,
#  216600,
#  38054,
#  244608,
#  203427,
#  204472,
#  218479,
#  95064,
#  69779,
#  158275,
#  272738,
#  220517,
#  125678,
#  171669,
#  218121,
#  554,
#  298069,
#  174570,
#  193214,
#  19600,
#  214029,
#  154086,
#  939,
#  219215,
#  212402,
#  56692,
#  180680,
#  161866,
#  66505,
#  165838,
#  25669,
#  131646,
#  224,
#  283863,
#  72225,
#  72287,
#  200077,
#  178336,
#  207691,
#  244114,
#  168917,
#  182340,
#  197405,
#  150999,
#  238992,
#  85897,
#  204027,
#  15817,
#  156776,
#  198740,
#  242804,
#  104710,
#  275467,
#  235488,
#  104363,
#  245643,
#  89409,
#  157403,
#  230080,
#  160018,
#  66056,
#  244331,
#  200954,
#  185589,
#  222514,
#  112,
#  1301,
#  141517,
#  248065,
#  157809,
#  210296,
#  1382,
#  75449,
#  45986,
#  22825,
#  284742,
#  171233,
#  60,
#  198454,
#  1822,
#  253284,
#  8203,
#  136991,
#  283864,
#  191231,
#  196526,
#  217449,
#  130176,
#  127518,
#  199966,
#  6830,
#  97903,
#  55427,
#  177524,
#  229892,
#  25568,
#  218509,
#  40793,
#  279613,
#  163154,
#  164949,
#  35052,
#  227515,
#  195314,
#  67492,
#  823,
#  122522,
#  35497,
#  254386,
#  135382,
#  18100,
#  244654,
#  551,
#  197070,
#  283393,
#  153065,
#  91536,
#  221,
#  21523,
#  159473,
#  23540,
#  194880,
#  217861,
#  306040,
#  228504,
#  152162,
#  71671,
#  142326,
#  1608,
#  164265,
#  134352,
#  229265,
#  285984,
#  1634,
#  94246,
#  5737,
#  68264,
#  183571,
#  182694,
#  156091,
#  207336,
#  8045,
#  223750,
#  184151,
#  137649,
#  316377,
#  175324,
#  218074,
#  17329,
#  216092,
#  145639,
#  264052,
#  176544,
#  95103,
#  124,
#  146312,
#  16992,
#  27364,
#  24068,
#  221318,
#  327,
#  183880,
#  187377,
#  44163,
#  17396,
#  833,
#  121410,
#  191300,
#  175199,
#  161882,
#  242684,
#  37836,
#  34084,
#  37628,
#  247236,
#  104020,
#  151007,
#  681,
#  208024,
#  91080,
#  195162,
#  272739,
#  163642,
#  290359,
#  230933,
#  176371,
#  300877,
#  154246,
#  140933,
#  8989,
#  234669,
#  181796,
#  278,
#  50768,
#  121297,
#  329465,
#  204836,
#  141423,
#  244049,
#  284818,
#  257518]

# %%
idList= ['174430', '161936']
categorylist=[]
for a in idlist:
    response = get_game_metadata(str(a))
    res=listify_game_metadata(response)
    for t in res[0]:
        categorylist.append([a,t[1]])
print(res)
categorylist
# Out:
# [[('2', 'Card Game'), ('2', 'Fantasy'), ('5', 'Economic'), ('5', 'Territory Building'), ('7', 'Abstract Strategy'), ('5', 'Economic'), ('5', 'Territory Building'), ('1', 'Economic'), ('1', 'Negotiation'), ('1', 'Political'), ('8', 'Civilization'), ('8', 'Fantasy')]]
# [[174430, 'Economic'],
#  [174430, 'Negotiation'],
#  [174430, 'Political'],
#  [174430, 'Abstract Strategy'],
#  [174430, 'Ancient'],
#  [174430, 'Ancient'],
#  [174430, 'Abstract Strategy'],
#  [174430, 'Medieval'],
#  [161936, 'Economic'],
#  [161936, 'Negotiation'],
#  [161936, 'Political'],
#  [161936, 'Civilization'],
#  [161936, 'Nautical'],
#  [161936, 'Economic'],
#  [161936, 'Negotiation'],
#  [161936, 'Political'],
#  [161936, 'Exploration'],
#  [161936, 'Abstract Strategy'],
#  [161936, 'Medieval'],
#  [161936, 'Civilization'],
#  [161936, 'Nautical'],
#  [224517, 'Card Game'],
#  [224517, 'Fantasy'],
#  [224517, 'Card Game'],
#  [224517, 'Fantasy'],
#  [224517, 'Ancient'],
#  [224517, 'Economic'],
#  [224517, 'Territory Building'],
#  [224517, 'Economic'],
#  [224517, 'Negotiation'],
#  [224517, 'Political'],
#  [224517, 'Abstract Strategy'],
#  [167791, 'Economic'],
#  [167791, 'Negotiation'],
#  [167791, 'Political'],
#  [167791, 'Civilization'],
#  [167791, 'Nautical'],
#  [167791, 'Abstract Strategy'],
#  [167791, 'Abstract Strategy'],
#  [167791, 'Exploration'],
#  [167791, 'Economic'],
#  [167791, 'Negotiation'],
#  [167791, 'Political'],
#  [291457, 'Card Game'],
#  [291457, 'Fantasy'],
#  [291457, 'Exploration'],
#  [291457, 'Economic'],
#  [291457, 'Negotiation'],
#  [291457, 'Political'],
#  [291457, 'Ancient'],
#  [291457, 'Economic'],
#  [291457, 'Territory Building'],
#  [291457, 'Abstract Strategy'],
#  [233078, 'Card Game'],
#  [233078, 'Fantasy'],
#  [233078, 'Abstract Strategy'],
#  [233078, 'Medieval'],
#  [233078, 'Abstract Strategy'],
#  [233078, 'Medieval'],
#  [233078, 'Abstract Strategy'],
#  [233078, 'Civilization'],
#  [233078, 'Fantasy'],
#  [220308, 'Card Game'],
#  [220308, 'Fantasy'],
#  [220308, 'Card Game'],
#  [220308, 'Fantasy'],
#  [220308, 'Abstract Strategy'],
#  [220308, 'Medieval'],
#  [220308, 'Civilization'],
#  [220308, 'Fantasy'],
#  [187645, 'Economic'],
#  [187645, 'Negotiation'],
#  [187645, 'Political'],
#  [187645, 'Civilization'],
#  [187645, 'Fantasy'],
#  [187645, 'Abstract Strategy'],
#  [187645, 'Civilization'],
#  [187645, 'Nautical'],
#  [187645, 'Ancient'],
#  [187645, 'Economic'],
#  [187645, 'Territory Building'],
#  [182028, 'Economic'],
#  [182028, 'Negotiation'],
#  [182028, 'Political'],
#  [182028, 'Civilization'],
#  [182028, 'Fantasy'],
#  [182028, 'Card Game'],
#  [182028, 'Fantasy'],
#  [182028, 'Card Game'],
#  [182028, 'Fantasy'],
#  [182028, 'Civilization'],
#  [182028, 'Fantasy'],
#  [193738, 'Economic'],
#  [193738, 'Negotiation'],
#  [193738, 'Political'],
#  [193738, 'Exploration'],
#  [193738, 'Abstract Strategy'],
#  [193738, 'Medieval'],
#  [193738, 'Abstract Strategy'],
#  [193738, 'Abstract Strategy'],
#  [193738, 'Medieval'],
#  [193738, 'Civilization'],
#  [193738, 'Fantasy'],
#  [162886, 'Economic'],
#  [162886, 'Negotiation'],
#  [162886, 'Political'],
#  [162886, 'Civilization'],
#  [162886, 'Nautical'],
#  [162886, 'Card Game'],
#  [162886, 'Fantasy'],
#  [162886, 'Civilization'],
#  [162886, 'Fantasy'],
#  [162886, 'Civilization'],
#  [162886, 'Fantasy'],
#  [162886, 'Civilization'],
#  [162886, 'Nautical'],
#  [12333, 'Economic'],
#  [12333, 'Negotiation'],
#  [12333, 'Political'],
#  [12333, 'Card Game'],
#  [12333, 'Fantasy'],
#  [12333, 'Abstract Strategy'],
#  [12333, 'Medieval'],
#  [12333, 'Abstract Strategy'],
#  [12333, 'Medieval'],
#  [12333, 'Abstract Strategy'],
#  [12333, 'Medieval'],
#  [115746, 'Economic'],
#  [115746, 'Negotiation'],
#  [115746, 'Political'],
#  [115746, 'Economic'],
#  [115746, 'Negotiation'],
#  [115746, 'Political'],
#  [115746, 'Economic'],
#  [115746, 'Territory Building'],
#  [115746, 'Abstract Strategy'],
#  [115746, 'Ancient'],
#  [115746, 'Civilization'],
#  [115746, 'Nautical'],
#  [169786, 'Economic'],
#  [169786, 'Negotiation'],
#  [169786, 'Political'],
#  [169786, 'Civilization'],
#  [169786, 'Nautical'],
#  [169786, 'Exploration'],
#  [169786, 'Abstract Strategy'],
#  [169786, 'Civilization'],
#  [169786, 'Fantasy'],
#  [169786, 'Civilization'],
#  [169786, 'Nautical'],
#  [84876, 'Civilization'],
#  [84876, 'Fantasy'],
#  [84876, 'Ancient'],
#  [84876, 'Civilization'],
#  [84876, 'Fantasy'],
#  [84876, 'Abstract Strategy'],
#  [84876, 'Civilization'],
#  [84876, 'Nautical'],
#  [173346, 'Economic'],
#  [173346, 'Negotiation'],
#  [173346, 'Political'],
#  [173346, 'Abstract Strategy'],
#  [173346, 'Abstract Strategy'],
#  [173346, 'Medieval'],
#  [173346, 'Abstract Strategy'],
#  [173346, 'Medieval'],
#  [173346, 'Ancient'],
#  [173346, 'Civilization'],
#  [173346, 'Nautical'],
#  [120677, 'Economic'],
#  [120677, 'Negotiation'],
#  [120677, 'Political'],
#  [120677, 'Card Game'],
#  [120677, 'Fantasy'],
#  [120677, 'Civilization'],
#  [120677, 'Nautical'],
#  [120677, 'Abstract Strategy'],
#  [120677, 'Abstract Strategy'],
#  [124361, 'Economic'],
#  [124361, 'Negotiation'],
#  [124361, 'Political'],
#  [124361, 'Card Game'],
#  [124361, 'Fantasy'],
#  [124361, 'Ancient'],
#  [124361, 'Abstract Strategy'],
#  [124361, 'Medieval'],
#  [124361, 'Civilization'],
#  [124361, 'Nautical'],
#  [124361, 'Economic'],
#  [124361, 'Negotiation'],
#  [124361, 'Political'],
#  [28720, 'Card Game'],
#  [28720, 'Fantasy'],
#  [28720, 'Civilization'],
#  [28720, 'Fantasy'],
#  [28720, 'Abstract Strategy'],
#  [28720, 'Card Game'],
#  [28720, 'Fantasy'],
#  [266192, 'Card Game'],
#  [266192, 'Fantasy'],
#  [266192, 'Civilization'],
#  [266192, 'Nautical'],
#  [266192, 'Civilization'],
#  [266192, 'Nautical'],
#  [266192, 'Economic'],
#  [266192, 'Negotiation'],
#  [266192, 'Political'],
#  [266192, 'Exploration'],
#  [266192, 'Card Game'],
#  [266192, 'Fantasy'],
#  [167355, 'Economic'],
#  [167355, 'Negotiation'],
#  [167355, 'Political'],
#  [167355, 'Civilization'],
#  [167355, 'Nautical'],
#  [167355, 'Abstract Strategy'],
#  [167355, 'Abstract Strategy'],
#  [167355, 'Medieval'],
#  [167355, 'Economic'],
#  [167355, 'Territory Building'],
#  [167355, 'Economic'],
#  [167355, 'Territory Building'],
#  [177736, 'Economic'],
#  [177736, 'Negotiation'],
#  [177736, 'Political'],
#  [177736, 'Abstract Strategy'],
#  [177736, 'Abstract Strategy'],
#  [177736, 'Abstract Strategy'],
#  [177736, 'Abstract Strategy'],
#  [177736, 'Medieval'],
#  [177736, 'Civilization'],
#  [177736, 'Nautical'],
#  [205637, 'Card Game'],
#  [205637, 'Fantasy'],
#  [205637, 'Economic'],
#  [205637, 'Territory Building'],
#  [205637, 'Civilization'],
#  [205637, 'Nautical'],
#  [205637, 'Abstract Strategy'],
#  [205637, 'Medieval'],
#  [205637, 'Abstract Strategy'],
#  [183394, 'Economic'],
#  [183394, 'Negotiation'],
#  [183394, 'Political'],
#  [183394, 'Civilization'],
#  [183394, 'Fantasy'],
#  [183394, 'Abstract Strategy'],
#  [183394, 'Medieval'],
#  [183394, 'Abstract Strategy'],
#  [183394, 'Medieval'],
#  [183394, 'Exploration'],
#  [183394, 'Ancient'],
#  [164928, 'Economic'],
#  [164928, 'Negotiation'],
#  [164928, 'Political'],
#  [164928, 'Civilization'],
#  [164928, 'Nautical'],
#  [164928, 'Ancient'],
#  [164928, 'Exploration'],
#  [164928, 'Card Game'],
#  [164928, 'Fantasy'],
#  [164928, 'Civilization'],
#  [164928, 'Fantasy'],
#  [96848, 'Exploration'],
#  [96848, 'Civilization'],
#  [96848, 'Nautical'],
#  [96848, 'Civilization'],
#  [96848, 'Fantasy'],
#  [96848, 'Ancient'],
#  [96848, 'Civilization'],
#  [96848, 'Fantasy'],
#  [237182, 'Card Game'],
#  [237182, 'Fantasy'],
#  [237182, 'Abstract Strategy'],
#  [237182, 'Medieval'],
#  [237182, 'Abstract Strategy'],
#  [237182, 'Economic'],
#  [237182, 'Negotiation'],
#  [237182, 'Political'],
#  [237182, 'Civilization'],
#  [237182, 'Fantasy'],
#  [237182, 'Card Game'],
#  [237182, 'Fantasy'],
#  [199792, 'Economic'],
#  [199792, 'Negotiation'],
#  [199792, 'Political'],
#  [199792, 'Exploration'],
#  [199792, 'Exploration'],
#  [199792, 'Abstract Strategy'],
#  [199792, 'Exploration'],
#  [199792, 'Card Game'],
#  [199792, 'Fantasy'],
#  [3076, 'Abstract Strategy'],
#  [3076, 'Medieval'],
#  [3076, 'Abstract Strategy'],
#  [3076, 'Civilization'],
#  [3076, 'Nautical'],
#  [102794, 'Economic'],
#  [102794, 'Negotiation'],
#  [102794, 'Political'],
#  [102794, 'Card Game'],
#  [102794, 'Fantasy'],
#  [102794, 'Abstract Strategy'],
#  [102794, 'Exploration'],
#  [102794, 'Ancient'],
#  [175914, 'Economic'],
#  [175914, 'Negotiation'],
#  [175914, 'Political'],
#  [175914, 'Abstract Strategy'],
#  [175914, 'Economic'],
#  [175914, 'Territory Building'],
#  [175914, 'Exploration'],
#  [175914, 'Economic'],
#  [175914, 'Negotiation'],
#  [175914, 'Political'],
#  [175914, 'Ancient'],
#  [31260, 'Abstract Strategy'],
#  [31260, 'Medieval'],
#  [31260, 'Economic'],
#  [31260, 'Negotiation'],
#  [31260, 'Political'],
#  [31260, 'Card Game'],
#  [31260, 'Fantasy'],
#  [31260, 'Civilization'],
#  [31260, 'Nautical'],
#  [170216, 'Economic'],
#  [170216, 'Negotiation'],
#  [170216, 'Political'],
#  [170216, 'Abstract Strategy'],
#  [170216, 'Card Game'],
#  [170216, 'Fantasy'],
#  [170216, 'Economic'],
#  [170216, 'Negotiation'],
#  [170216, 'Political'],
#  [170216, 'Civilization'],
#  [170216, 'Nautical'],
#  [205059, 'Card Game'],
#  [205059, 'Fantasy'],
#  [205059, 'Economic'],
#  [205059, 'Territory Building'],
#  [205059, 'Economic'],
#  [205059, 'Territory Building'],
#  [205059, 'Exploration'],
#  [221107, 'Card Game'],
#  [221107, 'Fantasy'],
#  [221107, 'Card Game'],
#  [221107, 'Fantasy'],
#  [221107, 'Economic'],
#  [221107, 'Negotiation'],
#  [221107, 'Political'],
#  [221107, 'Economic'],
#  [221107, 'Negotiation'],
#  [221107, 'Political'],
#  [221107, 'Abstract Strategy'],
#  [276025, 'Card Game'],
#  [276025, 'Fantasy'],
#  [276025, 'Abstract Strategy'],
#  [276025, 'Civilization'],
#  [276025, 'Nautical'],
#  [276025, 'Card Game'],
#  [276025, 'Fantasy'],
#  [276025, 'Economic'],
#  [276025, 'Territory Building'],
#  [316554, 'Abstract Strategy'],
#  [316554, 'Medieval'],
#  [316554, 'Economic'],
#  [316554, 'Negotiation'],
#  [316554, 'Political'],
#  [316554, 'Civilization'],
#  [316554, 'Nautical'],
#  [316554, 'Economic'],
#  [316554, 'Territory Building'],
#  [316554, 'Economic'],
#  [316554, 'Territory Building'],
#  [316554, 'Ancient'],
#  [285774, 'Card Game'],
#  [285774, 'Fantasy'],
#  [285774, 'Civilization'],
#  [285774, 'Fantasy'],
#  [285774, 'Economic'],
#  [285774, 'Territory Building'],
#  [285774, 'Abstract Strategy'],
#  [285774, 'Abstract Strategy'],
#  [285774, 'Ancient'],
#  [180263, 'Economic'],
#  [180263, 'Negotiation'],
#  [180263, 'Political'],
#  [180263, 'Civilization'],
#  [180263, 'Fantasy'],
#  [180263, 'Card Game'],
#  [180263, 'Fantasy'],
#  [180263, 'Civilization'],
#  [180263, 'Nautical'],
#  [180263, 'Abstract Strategy'],
#  [180263, 'Medieval'],
#  [284083, 'Card Game'],
#  [284083, 'Fantasy'],
#  [284083, 'Civilization'],
#  [284083, 'Fantasy'],
#  [284083, 'Ancient'],
#  [284083, 'Civilization'],
#  [284083, 'Fantasy'],
#  [284083, 'Abstract Strategy'],
#  [284083, 'Medieval'],
#  [192135, 'Economic'],
#  [192135, 'Negotiation'],
#  [192135, 'Political'],
#  [192135, 'Exploration'],
#  [192135, 'Card Game'],
#  [192135, 'Fantasy'],
#  [192135, 'Economic'],
#  [192135, 'Negotiation'],
#  [192135, 'Political'],
#  [192135, 'Abstract Strategy'],
#  [192135, 'Medieval'],
#  [192135, 'Economic'],
#  [192135, 'Territory Building'],
#  [266507, 'Card Game'],
#  [266507, 'Fantasy'],
#  [266507, 'Civilization'],
#  [266507, 'Nautical'],
#  [266507, 'Civilization'],
#  [266507, 'Nautical'],
#  [266507, 'Economic'],
#  [266507, 'Territory Building'],
#  [266507, 'Abstract Strategy'],
#  [247763, 'Card Game'],
#  [247763, 'Fantasy'],
#  [247763, 'Ancient'],
#  [247763, 'Abstract Strategy'],
#  [247763, 'Abstract Strategy'],
#  [247763, 'Civilization'],
#  [247763, 'Nautical'],
#  [247763, 'Abstract Strategy'],
#  [247763, 'Medieval'],
#  [55690, 'Economic'],
#  [55690, 'Territory Building'],
#  [55690, 'Economic'],
#  [55690, 'Territory Building'],
#  [55690, 'Civilization'],
#  [55690, 'Nautical'],
#  [55690, 'Exploration'],
#  [126163, 'Economic'],
#  [126163, 'Negotiation'],
#  [126163, 'Political'],
#  [126163, 'Card Game'],
#  [126163, 'Fantasy'],
#  [126163, 'Civilization'],
#  [126163, 'Nautical'],
#  [126163, 'Economic'],
#  [126163, 'Negotiation'],
#  [126163, 'Political'],
#  [126163, 'Civilization'],
#  [126163, 'Nautical'],
#  [126163, 'Abstract Strategy'],
#  [126163, 'Medieval'],
#  [2651, 'Card Game'],
#  [2651, 'Fantasy'],
#  [2651, 'Civilization'],
#  [2651, 'Nautical'],
#  [2651, 'Economic'],
#  [2651, 'Territory Building'],
#  [2651, 'Economic'],
#  [2651, 'Negotiation'],
#  [2651, 'Political'],
#  [185343, 'Economic'],
#  [185343, 'Negotiation'],
#  [185343, 'Political'],
#  [185343, 'Civilization'],
#  [185343, 'Fantasy'],
#  [185343, 'Economic'],
#  [185343, 'Territory Building'],
#  [185343, 'Abstract Strategy'],
#  [185343, 'Medieval'],
#  [185343, 'Ancient'],
#  [185343, 'Abstract Strategy'],
#  [185343, 'Medieval'],
#  [209010, 'Card Game'],
#  [209010, 'Fantasy'],
#  [209010, 'Exploration'],
#  [209010, 'Economic'],
#  [209010, 'Negotiation'],
#  [209010, 'Political'],
#  [164153, 'Economic'],
#  [164153, 'Negotiation'],
#  [164153, 'Political'],
#  [164153, 'Civilization'],
#  [164153, 'Nautical'],
#  [164153, 'Ancient'],
#  [164153, 'Economic'],
#  [164153, 'Negotiation'],
#  [164153, 'Political'],
#  [164153, 'Economic'],
#  [164153, 'Territory Building'],
#  [164153, 'Abstract Strategy'],
#  [164153, 'Medieval'],
#  [216132, 'Card Game'],
#  [216132, 'Fantasy'],
#  [216132, 'Economic'],
#  [216132, 'Negotiation'],
#  [216132, 'Political'],
#  [216132, 'Civilization'],
#  [216132, 'Nautical'],
#  [216132, 'Economic'],
#  [216132, 'Negotiation'],
#  [216132, 'Political'],
#  [216132, 'Abstract Strategy'],
#  [216132, 'Medieval'],
#  [216132, 'Card Game'],
#  [216132, 'Fantasy'],
#  [251247, 'Card Game'],
#  [251247, 'Fantasy'],
#  [251247, 'Economic'],
#  [251247, 'Territory Building'],
#  [251247, 'Economic'],
#  [251247, 'Negotiation'],
#  [251247, 'Political'],
#  [251247, 'Card Game'],
#  [251247, 'Fantasy'],
#  [251247, 'Ancient'],
#  [251247, 'Abstract Strategy'],
#  [35677, 'Abstract Strategy'],
#  [35677, 'Medieval'],
#  [35677, 'Economic'],
#  [35677, 'Territory Building'],
#  [35677, 'Civilization'],
#  [35677, 'Nautical'],
#  [35677, 'Abstract Strategy'],
#  [35677, 'Abstract Strategy'],
#  [230802, 'Card Game'],
#  [230802, 'Fantasy'],
#  [230802, 'Abstract Strategy'],
#  [230802, 'Medieval'],
#  [230802, 'Civilization'],
#  [230802, 'Fantasy'],
#  [230802, 'Card Game'],
#  [230802, 'Fantasy'],
#  [184267, 'Economic'],
#  [184267, 'Negotiation'],
#  [184267, 'Political'],
#  [184267, 'Civilization'],
#  [184267, 'Fantasy'],
#  [184267, 'Ancient'],
#  [184267, 'Card Game'],
#  [184267, 'Fantasy'],
#  [184267, 'Civilization'],
#  [184267, 'Nautical'],
#  [184267, 'Abstract Strategy'],
#  [72125, 'Abstract Strategy'],
#  [72125, 'Card Game'],
#  [72125, 'Fantasy'],
#  [72125, 'Economic'],
#  [72125, 'Negotiation'],
#  [72125, 'Political'],
#  [72125, 'Card Game'],
#  [72125, 'Fantasy'],
#  [72125, 'Economic'],
#  [72125, 'Territory Building'],
#  [312484, 'Abstract Strategy'],
#  [312484, 'Medieval'],
#  [312484, 'Economic'],
#  [312484, 'Negotiation'],
#  [312484, 'Political'],
#  [312484, 'Card Game'],
#  [312484, 'Fantasy'],
#  [312484, 'Ancient'],
#  [312484, 'Civilization'],
#  [312484, 'Fantasy'],
#  [312484, 'Ancient'],
#  [25613, 'Card Game'],
#  [25613, 'Fantasy'],
#  [25613, 'Economic'],
#  [25613, 'Territory Building'],
#  [25613, 'Civilization'],
#  [25613, 'Nautical'],
#  [25613, 'Economic'],
#  [25613, 'Negotiation'],
#  [25613, 'Political'],
#  [25613, 'Abstract Strategy'],
#  [25613, 'Medieval'],
#  [125153, 'Economic'],
#  [125153, 'Negotiation'],
#  [125153, 'Political'],
#  [125153, 'Card Game'],
#  [125153, 'Fantasy'],
#  [125153, 'Economic'],
#  [125153, 'Territory Building'],
#  [125153, 'Economic'],
#  [125153, 'Negotiation'],
#  [125153, 'Political'],
#  [125153, 'Economic'],
#  [125153, 'Territory Building'],
#  [125153, 'Abstract Strategy'],
#  [125153, 'Medieval'],
#  [256960, 'Card Game'],
#  [256960, 'Fantasy'],
#  [256960, 'Economic'],
#  [256960, 'Territory Building'],
#  [256960, 'Civilization'],
#  [256960, 'Nautical'],
#  [256960, 'Exploration'],
#  [256960, 'Civilization'],
#  [256960, 'Nautical'],
#  [124742, 'Economic'],
#  [124742, 'Negotiation'],
#  [124742, 'Political'],
#  [124742, 'Card Game'],
#  [124742, 'Fantasy'],
#  [124742, 'Ancient'],
#  [124742, 'Abstract Strategy'],
#  [124742, 'Ancient'],
#  [124742, 'Card Game'],
#  [124742, 'Fantasy'],
#  [191189, 'Economic'],
#  [191189, 'Negotiation'],
#  [191189, 'Political'],
#  [191189, 'Exploration'],
#  [191189, 'Economic'],
#  [191189, 'Negotiation'],
#  [191189, 'Political'],
#  [191189, 'Economic'],
#  [191189, 'Negotiation'],
#  [191189, 'Political'],
#  [191189, 'Civilization'],
#  [191189, 'Fantasy'],
#  [191189, 'Exploration'],
#  [161533, 'Economic'],
#  [161533, 'Negotiation'],
#  [161533, 'Political'],
#  [161533, 'Civilization'],
#  [161533, 'Nautical'],
#  [161533, 'Economic'],
#  [161533, 'Negotiation'],
#  [161533, 'Political'],
#  [161533, 'Economic'],
#  [161533, 'Territory Building'],
#  [161533, 'Abstract Strategy'],
#  [161533, 'Medieval'],
#  [161533, 'Abstract Strategy'],
#  [161533, 'Medieval'],
#  [121921, 'Economic'],
#  [121921, 'Negotiation'],
#  [121921, 'Political'],
#  [121921, 'Card Game'],
#  [121921, 'Fantasy'],
#  [121921, 'Economic'],
#  [121921, 'Negotiation'],
#  [121921, 'Political'],
#  [121921, 'Exploration'],
#  [121921, 'Card Game'],
#  [121921, 'Fantasy'],
#  [121921, 'Economic'],
#  [121921, 'Negotiation'],
#  [121921, 'Political'],
#  [159675, 'Economic'],
#  [159675, 'Negotiation'],
#  [159675, 'Political'],
#  [159675, 'Economic'],
#  [159675, 'Territory Building'],
#  [159675, 'Exploration'],
#  [159675, 'Civilization'],
#  [159675, 'Nautical'],
#  [159675, 'Abstract Strategy'],
#  [159675, 'Economic'],
#  [159675, 'Territory Building'],
#  [521, 'Economic'],
#  [521, 'Territory Building'],
#  [521, 'Card Game'],
#  [521, 'Fantasy'],
#  [521, 'Economic'],
#  [521, 'Negotiation'],
#  [521, 'Political'],
#  [244521, 'Card Game'],
#  [244521, 'Fantasy'],
#  [244521, 'Ancient'],
#  [244521, 'Ancient'],
#  [244521, 'Economic'],
#  [244521, 'Territory Building'],
#  [244521, 'Card Game'],
#  [244521, 'Fantasy'],
#  [244521, 'Economic'],
#  [244521, 'Negotiation'],
#  [244521, 'Political'],
#  [171623, 'Economic'],
#  [171623, 'Negotiation'],
#  [171623, 'Political'],
#  [171623, 'Abstract Strategy'],
#  [171623, 'Economic'],
#  [171623, 'Negotiation'],
#  [171623, 'Political'],
#  [171623, 'Civilization'],
#  [171623, 'Nautical'],
#  [171623, 'Card Game'],
#  [171623, 'Fantasy'],
#  [171623, 'Abstract Strategy'],
#  [171623, 'Medieval'],
#  [28143, 'Card Game'],
#  [28143, 'Fantasy'],
#  [28143, 'Civilization'],
#  [28143, 'Fantasy'],
#  [28143, 'Economic'],
#  [28143, 'Negotiation'],
#  [28143, 'Political'],
#  [28143, 'Ancient'],
#  [28143, 'Abstract Strategy'],
#  [28143, 'Medieval'],
#  [266810, 'Card Game'],
#  [266810, 'Fantasy'],
#  [266810, 'Civilization'],
#  [266810, 'Nautical'],
#  [266810, 'Civilization'],
#  [266810, 'Nautical'],
#  [266810, 'Civilization'],
#  [266810, 'Fantasy'],
#  [266810, 'Economic'],
#  [266810, 'Negotiation'],
#  [266810, 'Political'],
#  [229853, 'Card Game'],
#  [229853, 'Fantasy'],
#  [229853, 'Card Game'],
#  [229853, 'Fantasy'],
#  [229853, 'Exploration'],
#  [229853, 'Civilization'],
#  [229853, 'Fantasy'],
#  [229853, 'Economic'],
#  [229853, 'Territory Building'],
#  [229853, 'Abstract Strategy'],
#  [229853, 'Medieval'],
#  [246900, 'Card Game'],
#  [246900, 'Fantasy'],
#  [246900, 'Ancient'],
#  [246900, 'Civilization'],
#  [246900, 'Nautical'],
#  [246900, 'Exploration'],
#  [201808, 'Card Game'],
#  [201808, 'Fantasy'],
#  [201808, 'Economic'],
#  [201808, 'Negotiation'],
#  [201808, 'Political'],
#  [201808, 'Civilization'],
#  [201808, 'Fantasy'],
#  [201808, 'Civilization'],
#  [201808, 'Fantasy'],
#  [68448, 'Civilization'],
#  [68448, 'Nautical'],
#  [68448, 'Civilization'],
#  [68448, 'Fantasy'],
#  [68448, 'Ancient'],
#  [68448, 'Ancient'],
#  [68448, 'Civilization'],
#  [68448, 'Fantasy'],
#  [157354, 'Economic'],
#  [157354, 'Negotiation'],
#  [157354, 'Political'],
#  [157354, 'Economic'],
#  [157354, 'Territory Building'],
#  [157354, 'Abstract Strategy'],
#  [157354, 'Abstract Strategy'],
#  [157354, 'Medieval'],
#  [157354, 'Economic'],
#  [157354, 'Territory Building'],
#  [157354, 'Ancient'],
#  [62219, 'Civilization'],
#  [62219, 'Nautical'],
#  [62219, 'Card Game'],
#  [62219, 'Fantasy'],
#  [62219, 'Card Game'],
#  [62219, 'Fantasy'],
#  [62219, 'Economic'],
#  [62219, 'Negotiation'],
#  [62219, 'Political'],
#  [62219, 'Exploration'],
#  [110327, 'Economic'],
#  [110327, 'Negotiation'],
#  [110327, 'Political'],
#  [110327, 'Economic'],
#  [110327, 'Negotiation'],
#  [110327, 'Political'],
#  [110327, 'Abstract Strategy'],
#  [110327, 'Medieval'],
#  [110327, 'Card Game'],
#  [110327, 'Fantasy'],
#  [110327, 'Abstract Strategy'],
#  [200680, 'Card Game'],
#  [200680, 'Fantasy'],
#  [200680, 'Civilization'],
#  [200680, 'Nautical'],
#  [200680, 'Civilization'],
#  [200680, 'Fantasy'],
#  [122515, 'Economic'],
#  [122515, 'Negotiation'],
#  [122515, 'Political'],
#  [122515, 'Card Game'],
#  [122515, 'Fantasy'],
#  [122515, 'Card Game'],
#  [122515, 'Fantasy'],
#  [122515, 'Economic'],
#  [122515, 'Territory Building'],
#  [122515, 'Economic'],
#  [122515, 'Negotiation'],
#  [122515, 'Political'],
#  [122515, 'Economic'],
#  [122515, 'Territory Building'],
#  [264220, 'Card Game'],
#  [264220, 'Fantasy'],
#  [264220, 'Civilization'],
#  [264220, 'Nautical'],
#  [264220, 'Ancient'],
#  [264220, 'Card Game'],
#  [264220, 'Fantasy'],
#  [264220, 'Card Game'],
#  [264220, 'Fantasy'],
#  [236457, 'Card Game'],
#  [236457, 'Fantasy'],
#  [236457, 'Abstract Strategy'],
#  [236457, 'Medieval'],
#  [236457, 'Civilization'],
#  [236457, 'Nautical'],
#  [236457, 'Ancient'],
#  [236457, 'Economic'],
#  [236457, 'Territory Building'],
#  [236457, 'Abstract Strategy'],
#  [18602, 'Economic'],
#  [18602, 'Negotiation'],
#  [18602, 'Political'],
#  [18602, 'Civilization'],
#  [18602, 'Fantasy'],
#  [18602, 'Civilization'],
#  [18602, 'Nautical'],
#  [18602, 'Card Game'],
#  [18602, 'Fantasy'],
#  [93, 'Exploration'],
#  [93, 'Abstract Strategy'],
#  [93, 'Medieval'],
#  [182874, 'Economic'],
#  [182874, 'Negotiation'],
#  [182874, 'Political'],
#  [182874, 'Civilization'],
#  [182874, 'Fantasy'],
#  [182874, 'Card Game'],
#  [182874, 'Fantasy'],
#  [182874, 'Civilization'],
#  [182874, 'Fantasy'],
#  [182874, 'Abstract Strategy'],
#  [182874, 'Ancient'],
#  [12493, 'Economic'],
#  [12493, 'Negotiation'],
#  [12493, 'Political'],
#  [12493, 'Card Game'],
#  [12493, 'Fantasy'],
#  [12493, 'Ancient'],
#  [12493, 'Exploration'],
#  [12493, 'Abstract Strategy'],
#  [12493, 'Medieval'],
#  [37111, 'Abstract Strategy'],
#  [37111, 'Medieval'],
#  [37111, 'Abstract Strategy'],
#  [37111, 'Economic'],
#  [37111, 'Negotiation'],
#  [37111, 'Political'],
#  [37111, 'Economic'],
#  [37111, 'Negotiation'],
#  [37111, 'Political'],
#  [37111, 'Economic'],
#  [37111, 'Negotiation'],
#  [37111, 'Political'],
#  [146021, 'Economic'],
#  [146021, 'Negotiation'],
#  [146021, 'Political'],
#  [146021, 'Ancient'],
#  [146021, 'Civilization'],
#  [146021, 'Nautical'],
#  [146021, 'Card Game'],
#  [146021, 'Fantasy'],
#  [146021, 'Economic'],
#  [146021, 'Negotiation'],
#  [146021, 'Political'],
#  [73439, 'Abstract Strategy'],
#  [73439, 'Abstract Strategy'],
#  [73439, 'Medieval'],
#  [73439, 'Ancient'],
#  [73439, 'Abstract Strategy'],
#  [73439, 'Medieval'],
#  [73439, 'Exploration'],
#  [172386, 'Economic'],
#  [172386, 'Negotiation'],
#  [172386, 'Political'],
#  [172386, 'Abstract Strategy'],
#  [172386, 'Card Game'],
#  [172386, 'Fantasy'],
#  [172386, 'Abstract Strategy'],
#  [172386, 'Medieval'],
#  [172386, 'Civilization'],
#  [172386, 'Fantasy'],
#  [172386, 'Civilization'],
#  [172386, 'Nautical'],
#  [40834, 'Ancient'],
#  [40834, 'Civilization'],
#  [40834, 'Fantasy'],
#  [40834, 'Abstract Strategy'],
#  [40834, 'Medieval'],
#  [40834, 'Ancient'],
#  [205896, 'Card Game'],
#  [205896, 'Fantasy'],
#  [205896, 'Economic'],
#  [205896, 'Territory Building'],
#  [205896, 'Civilization'],
#  [205896, 'Fantasy'],
#  [205896, 'Exploration'],
#  [205896, 'Civilization'],
#  [205896, 'Nautical'],
#  [269385, 'Card Game'],
#  [269385, 'Fantasy'],
#  [269385, 'Civilization'],
#  [269385, 'Nautical'],
#  [269385, 'Exploration'],
#  [269385, 'Abstract Strategy'],
#  [269385, 'Medieval'],
#  [269385, 'Civilization'],
#  [269385, 'Fantasy'],
#  [269385, 'Economic'],
#  [269385, 'Territory Building'],
#  [163412, 'Economic'],
#  [163412, 'Negotiation'],
#  [163412, 'Political'],
#  [163412, 'Civilization'],
#  [163412, 'Nautical'],
#  [163412, 'Abstract Strategy'],
#  [163412, 'Medieval'],
#  [163412, 'Ancient'],
#  [163412, 'Economic'],
#  [163412, 'Negotiation'],
#  [163412, 'Political'],
#  [163412, 'Card Game'],
#  [163412, 'Fantasy'],
#  [170042, 'Economic'],
#  [170042, 'Negotiation'],
#  [170042, 'Political'],
#  [170042, 'Abstract Strategy'],
#  [170042, 'Ancient'],
#  [170042, 'Card Game'],
#  [170042, 'Fantasy'],
#  [144733, 'Economic'],
#  [144733, 'Negotiation'],
#  [144733, 'Political'],
#  [144733, 'Ancient'],
#  [144733, 'Ancient'],
#  [144733, 'Abstract Strategy'],
#  [144733, 'Abstract Strategy'],
#  [144733, 'Medieval'],
#  [144733, 'Abstract Strategy'],
#  [144733, 'Medieval'],
#  [42, 'Ancient'],
#  [42, 'Card Game'],
#  [42, 'Fantasy'],
#  [203993, 'Card Game'],
#  [203993, 'Fantasy'],
#  [203993, 'Abstract Strategy'],
#  [203993, 'Medieval'],
#  [203993, 'Exploration'],
#  [203993, 'Exploration'],
#  [203993, 'Abstract Strategy'],
#  [203993, 'Medieval'],
#  [281259, 'Card Game'],
#  [281259, 'Fantasy'],
#  [281259, 'Civilization'],
#  [281259, 'Fantasy'],
#  [281259, 'Economic'],
#  [281259, 'Negotiation'],
#  [281259, 'Political'],
#  [281259, 'Card Game'],
#  [281259, 'Fantasy'],
#  [281259, 'Economic'],
#  [281259, 'Territory Building'],
#  [281259, 'Exploration'],
#  [178900, 'Economic'],
#  [178900, 'Negotiation'],
#  [178900, 'Political'],
#  [178900, 'Abstract Strategy'],
#  [178900, 'Civilization'],
#  [178900, 'Fantasy'],
#  [178900, 'Exploration'],
#  [102680, 'Economic'],
#  [102680, 'Negotiation'],
#  [102680, 'Political'],
#  [102680, 'Card Game'],
#  [102680, 'Fantasy'],
#  [102680, 'Civilization'],
#  [102680, 'Nautical'],
#  [102680, 'Civilization'],
#  [102680, 'Fantasy'],
#  [132531, 'Economic'],
#  [132531, 'Negotiation'],
#  [132531, 'Political'],
#  [132531, 'Abstract Strategy'],
#  [132531, 'Medieval'],
#  [132531, 'Card Game'],
#  [132531, 'Fantasy'],
#  [132531, 'Economic'],
#  [132531, 'Territory Building'],
#  ...]

# %%
type(categorylist)
# Out:
# list

# %%
categories=pd.DataFrame(categorylist,columns=['id','categories'])
categories
# Out:
#           id         categories
# 0     174430           Economic
# 1     174430        Negotiation
# 2     174430          Political
# 3     174430  Abstract Strategy
# 4     174430            Ancient
# ...      ...                ...
# 9455  257518           Economic
# 9456  257518        Negotiation
# 9457  257518          Political
# 9458  257518       Civilization
# 9459  257518            Fantasy
#
# [9460 rows x 2 columns]

# %%
categories.to_csv('bgg_categories.csv')

# %%
categories['categories'] = categories.groupby(['id'])['categories'].transform(lambda x : ','.join(x))

# %%
categories = categories.drop_duplicates()
categories
# Out:
#           id                                         categories
# 0     174430  Economic,Negotiation,Political,Abstract Strate...
# 8     161936  Economic,Negotiation,Political,Civilization,Na...
# 21    224517  Card Game,Fantasy,Card Game,Fantasy,Ancient,Ec...
# 32    167791  Economic,Negotiation,Political,Civilization,Na...
# 43    291457  Card Game,Fantasy,Exploration,Economic,Negotia...
# ...      ...                                                ...
# 9409  204836  Card Game,Fantasy,Ancient,Civilization,Fantasy...
# 9418  141423  Economic,Negotiation,Political,Ancient,Economi...
# 9430  244049  Card Game,Fantasy,Ancient,Ancient,Ancient,Expl...
# 9436  284818  Card Game,Fantasy,Civilization,Fantasy,Ancient...
# 9448  257518  Card Game,Fantasy,Economic,Territory Building,...
#
# [1000 rows x 2 columns]

# %%
categories.to_csv('bgg_categories_drop.csv')

# %%
game_ranking=pd.read_csv('game_ranking.csv')
game_ranking.head()
# Out:
#    rank      id                          name  \
# 0     1  174430                    Gloomhaven
# 1     2  161936     Pandemic Legacy: Season 1
# 2     3  224517             Brass: Birmingham
# 3     4  167791             Terraforming Mars
# 4     5  291457  Gloomhaven: Jaws of the Lion
#
#                                          description  bggrating  avgrating  \
# 0  Vanquish monsters with strategic cardplay. Ful...      8.534       8.77
# 1  Mutating diseases are spreading around the wor...      8.453       8.61
# 2  Build networks, grow industries, and navigate ...      8.403       8.67
# 3  Compete with rival CEOs to make Mars habitable...      8.279       8.43
# 4  Vanquish monsters with strategic cardplay in a...      8.256       8.77
#
#    numvoter        date
# 0     44979  2021-08-10
# 1     43369  2021-08-10
# 2     22391  2021-08-10
# 3     69407  2021-08-10
# 4     12192  2021-08-10

# %%
ranking_category = pd.merge(game_ranking,categories, on ='id',how ='left')
ranking_category
# Out:
#      rank      id                          name  \
# 0       1  174430                    Gloomhaven
# 1       2  161936     Pandemic Legacy: Season 1
# 2       3  224517             Brass: Birmingham
# 3       4  167791             Terraforming Mars
# 4       5  291457  Gloomhaven: Jaws of the Lion
# ..    ...     ...                           ...
# 995   996  204836         Escape Room: The Game
# 996   997  141423        Dead Men Tell No Tales
# 997   998  244049                Forum Trajanum
# 998   999  284818                   Caylus 1303
# 999  1000  257518           Claustrophobia 1643
#
#                                            description  bggrating  avgrating  \
# 0    Vanquish monsters with strategic cardplay. Ful...      8.534       8.77
# 1    Mutating diseases are spreading around the wor...      8.453       8.61
# 2    Build networks, grow industries, and navigate ...      8.403       8.67
# 3    Compete with rival CEOs to make Mars habitable...      8.279       8.43
# 4    Vanquish monsters with strategic cardplay in a...      8.256       8.77
# ..                                                 ...        ...        ...
# 995  Solve puzzles and use the keys to stop the chr...      6.528       7.04
# 996  Work together as pirates to defeat enemies and...      6.527       7.13
# 997  Find out who's hiding in your Roman settlement...      6.527       7.32
# 998  Quarrel over action spaces (and player powers)...      6.525       7.60
# 999  Zealots and vagabonds brave unspeakable horror...      6.525       8.08
#
#      numvoter        date                                         categories
# 0       44979  2021-08-10  Economic,Negotiation,Political,Abstract Strate...
# 1       43369  2021-08-10  Economic,Negotiation,Political,Civilization,Na...
# 2       22391  2021-08-10  Card Game,Fantasy,Card Game,Fantasy,Ancient,Ec...
# 3       69407  2021-08-10  Economic,Negotiation,Political,Civilization,Na...
# 4       12192  2021-08-10  Card Game,Fantasy,Exploration,Economic,Negotia...
# ..        ...         ...                                                ...
# 995      3418  2021-08-10  Card Game,Fantasy,Ancient,Civilization,Fantasy...
# 996      3091  2021-08-10  Economic,Negotiation,Political,Ancient,Economi...
# 997      2172  2021-08-10  Card Game,Fantasy,Ancient,Ancient,Ancient,Expl...
# 998      1579  2021-08-10  Card Game,Fantasy,Civilization,Fantasy,Ancient...
# 999      1213  2021-08-10  Card Game,Fantasy,Economic,Territory Building,...
#
# [1000 rows x 9 columns]

# %%
ranking_category.to_csv('ranking_category.csv')
